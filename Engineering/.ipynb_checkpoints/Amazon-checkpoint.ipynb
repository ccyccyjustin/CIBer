# %% [markdown]
# ## 1. Dataset

# %% [markdown]
# repository_url: ```https://www.kaggle.com/datasets/sujalsuthar/amazon-delivery-dataset```
#
# Uncover insights into factors influencing delivery efficiency, identify areas for optimization, and explore the impact of various variables on the overall customer experience

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys
from importlib import reload

import seaborn as sns
from collections import defaultdict
from tqdm import tqdm
import inspect


sys.path.append('/Users/cheungjustin/PycharmProjects/CIBer')
import util as put
import stats as pstats
import analytics as pan
import plot as pplot
import geopy.distance

# %%
df = pd.read_csv('../Raw/amazon_delivery.csv', index_col=0)
df['Order_Date'] = pd.to_datetime(df['Order_Date'])
df['Order_Time'] = pd.to_timedelta(df['Order_Time'], errors='coerce') / np.timedelta64(1, 'm')
df['Pickup_Time'] = pd.to_timedelta(df['Pickup_Time'], errors='coerce') / np.timedelta64(1, 'm')

thres = 4.5
df['Dissatisfied'] = (df['Agent_Rating'] < thres)#.astype(int)
df['Delivery_Time'] = df['Delivery_Time'].astype(float)
df = df.drop(columns='Agent_Rating')

display(df)
print(df.dtypes)
# Out:
#                Agent_Age  Store_Latitude  Store_Longitude  Drop_Latitude  \
# Order_ID
# ialx566343618         37       22.745049        75.892471      22.765049
# akqg208421122         34       12.913041        77.683237      13.043041
# njpu434582536         23       12.914264        77.678400      12.924264
# rjto796129700         38       11.003669        76.976494      11.053669
# zguw716275638         32       12.972793        80.249982      13.012793
# ...                  ...             ...              ...            ...
# jlxf819993117         30       26.902328        75.794257      26.912328
# aevx342135787         21        0.000000         0.000000       0.070000
# xnek760674819         30       13.022394        80.242439      13.052394
# cynl434665991         20       11.001753        76.986241      11.041753
# nsyz997960170         23       23.351058        85.325731      23.431058
#
#                Drop_Longitude Order_Date  Order_Time  Pickup_Time     Weather  \
# Order_ID
# ialx566343618       75.912471 2022-03-19       690.0        705.0       Sunny
# akqg208421122       77.813237 2022-03-25      1185.0       1190.0      Stormy
# njpu434582536       77.688400 2022-03-19       510.0        525.0  Sandstorms
# rjto796129700       77.026494 2022-04-05      1080.0       1090.0       Sunny
# zguw716275638       80.289982 2022-03-26       810.0        825.0      Cloudy
# ...                       ...        ...         ...          ...         ...
# jlxf819993117       75.804257 2022-03-24       695.0        705.0       Windy
# aevx342135787        0.070000 2022-02-16      1195.0       1210.0       Windy
# xnek760674819       80.272439 2022-03-11      1430.0          5.0      Cloudy
# cynl434665991       77.026241 2022-03-07       815.0        820.0      Cloudy
# nsyz997960170       85.405731 2022-03-02      1030.0       1035.0         Fog
#
#                Traffic      Vehicle            Area  Delivery_Time  \
# Order_ID
# ialx566343618    High   motorcycle           Urban           120.0
# akqg208421122     Jam      scooter   Metropolitian           165.0
# njpu434582536     Low   motorcycle           Urban           130.0
# rjto796129700  Medium   motorcycle   Metropolitian           105.0
# zguw716275638    High      scooter   Metropolitian           150.0
# ...                ...          ...             ...            ...
# jlxf819993117    High   motorcycle   Metropolitian           160.0
# aevx342135787     Jam   motorcycle   Metropolitian           180.0
# xnek760674819     Low      scooter   Metropolitian            80.0
# cynl434665991    High   motorcycle   Metropolitian           130.0
# nsyz997960170  Medium      scooter   Metropolitian           180.0
#
#                   Category  Dissatisfied
# Order_ID
# ialx566343618     Clothing             0
# akqg208421122  Electronics             0
# njpu434582536       Sports             1
# rjto796129700    Cosmetics             0
# zguw716275638         Toys             0
# ...                    ...           ...
# jlxf819993117         Home             0
# aevx342135787      Jewelry             0
# xnek760674819         Home             0
# cynl434665991      Kitchen             0
# nsyz997960170    Cosmetics             0
#
# [43739 rows x 15 columns]
# Agent_Age                   int64
# Store_Latitude            float64
# Store_Longitude           float64
# Drop_Latitude             float64
# Drop_Longitude            float64
# Order_Date         datetime64[ns]
# Order_Time                float64
# Pickup_Time               float64
# Weather                    object
# Traffic                    object
# Vehicle                    object
# Area                       object
# Delivery_Time             float64
# Category                   object
# Dissatisfied                int64
# dtype: object

# %% [markdown]
# ## 2. EDA Wrapper

# %%
random_state = 4012
target = 'Dissatisfied'
dta = pan.DataAnalyzer(df, 
                       target=target, cont_thres=30, random_state=random_state)
# Out:
# Continuous Columns:
# 	Store_Latitude
# 	Store_Longitude
# 	Drop_Latitude
# 	Drop_Longitude
# 	Order_Time
# 	Pickup_Time
# 	Delivery_Time
# 	Order_Date
#
# Discrete Columns Encoding:
# 	Agent_Age: {15: 0, 20: 1, 21: 2, 22: 3, 23: 4, 24: 5, 25: 6, 26: 7, 27: 8, 28: 9, 29: 10, 30: 11, 31: 12, 32: 13, 33: 14, 34: 15, 35: 16, 36: 17, 37: 18, 38: 19, 39: 20, 50: 21}
# 	Weather: {'Cloudy': 0, 'Fog': 1, 'Sandstorms': 2, 'Stormy': 3, 'Sunny': 4, 'Windy': 5, 'nan': 6}
# 	Traffic: {'High ': 0, 'Jam ': 1, 'Low ': 2, 'Medium ': 3, 'NaN ': 4}
# 	Vehicle: {'bicycle ': 0, 'motorcycle ': 1, 'scooter ': 2, 'van': 3}
# 	Area: {'Metropolitian ': 0, 'Other': 1, 'Semi-Urban ': 2, 'Urban ': 3}
# 	Category: {'Apparel': 0, 'Books': 1, 'Clothing': 2, 'Cosmetics': 3, 'Electronics': 4, 'Grocery': 5, 'Home': 6, 'Jewelry': 7, 'Kitchen': 8, 'Outdoors': 9, 'Pet Supplies': 10, 'Shoes': 11, 'Skincare': 12, 'Snacks': 13, 'Sports': 14, 'Toys': 15}
# 	Dissatisfied: {0: 0, 1: 1}

# %%
dta.data_quality_check(check_zero=True, miss_thres=0.);

# %%
dta.dist_plot();

# %%
dta.corr_heatmap(corr_method='dcorr', cluster=True);
dta.corr_heatmap(corr_method='dcorr', partial=True, cluster=True, linkage_method='single');
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/pandas/core/internals/blocks.py:395: RuntimeWarning: invalid value encountered in sqrt
#   result = func(self.values, **kwargs)

# %% [markdown]
# ### 2.1 Update Features

# %%
df2 = df.copy()
missing_store = (df2[['Store_Latitude', 'Store_Longitude']].abs() < 1e-6).all(axis=1)
df2.loc[missing_store, ['Store_Latitude', 'Store_Longitude']] = np.nan

def calc_row_dist(row):
    store = (row['Store_Latitude'], row['Store_Longitude'])
    drop = (row['Drop_Latitude'], row['Drop_Longitude'])
    if (np.isfinite([*store, *drop])).all():
        return geopy.distance.geodesic(store, drop).km
    else:
        return np.nan
    
df2['Drop_Distance'] = df2.apply(calc_row_dist, axis=1)

# %%
wait_time = (df2['Pickup_Time'] - df2['Order_Time'])
df2['Wait_Time'] = wait_time[wait_time >= 0]

# %%
df2 = df2.drop(columns=['Drop_Latitude', 'Drop_Longitude', 'Pickup_Time'])
df2
# Out:
#                Agent_Age  Store_Latitude  Store_Longitude Order_Date  \
# Order_ID
# ialx566343618         37       22.745049        75.892471 2022-03-19
# akqg208421122         34       12.913041        77.683237 2022-03-25
# njpu434582536         23       12.914264        77.678400 2022-03-19
# rjto796129700         38       11.003669        76.976494 2022-04-05
# zguw716275638         32       12.972793        80.249982 2022-03-26
# ...                  ...             ...              ...        ...
# jlxf819993117         30       26.902328        75.794257 2022-03-24
# aevx342135787         21             NaN              NaN 2022-02-16
# xnek760674819         30       13.022394        80.242439 2022-03-11
# cynl434665991         20       11.001753        76.986241 2022-03-07
# nsyz997960170         23       23.351058        85.325731 2022-03-02
#
#                Order_Time     Weather  Traffic      Vehicle            Area  \
# Order_ID
# ialx566343618       690.0       Sunny    High   motorcycle           Urban
# akqg208421122      1185.0      Stormy     Jam      scooter   Metropolitian
# njpu434582536       510.0  Sandstorms     Low   motorcycle           Urban
# rjto796129700      1080.0       Sunny  Medium   motorcycle   Metropolitian
# zguw716275638       810.0      Cloudy    High      scooter   Metropolitian
# ...                   ...         ...      ...          ...             ...
# jlxf819993117       695.0       Windy    High   motorcycle   Metropolitian
# aevx342135787      1195.0       Windy     Jam   motorcycle   Metropolitian
# xnek760674819      1430.0      Cloudy     Low      scooter   Metropolitian
# cynl434665991       815.0      Cloudy    High   motorcycle   Metropolitian
# nsyz997960170      1030.0         Fog  Medium      scooter   Metropolitian
#
#                Delivery_Time     Category  Dissatisfied  Drop_Distance  \
# Order_ID
# ialx566343618          120.0     Clothing             0       3.020737
# akqg208421122          165.0  Electronics             0      20.143737
# njpu434582536          130.0       Sports             1       1.549693
# rjto796129700          105.0    Cosmetics             0       7.774497
# zguw716275638          150.0         Toys             0       6.197898
# ...                      ...          ...           ...            ...
# jlxf819993117          160.0         Home             0       1.488112
# aevx342135787          180.0      Jewelry             0            NaN
# xnek760674819           80.0         Home             0       4.648024
# cynl434665991          130.0      Kitchen             0       6.219668
# nsyz997960170          180.0    Cosmetics             0      12.057294
#
#                Wait_Time
# Order_ID
# ialx566343618       15.0
# akqg208421122        5.0
# njpu434582536       15.0
# rjto796129700       10.0
# zguw716275638       15.0
# ...                  ...
# jlxf819993117       10.0
# aevx342135787       15.0
# xnek760674819        NaN
# cynl434665991        5.0
# nsyz997960170        5.0
#
# [43739 rows x 14 columns]

# %%
dta = pan.DataAnalyzer(df2, 
                       target=target, cont_thres=30, random_state=random_state)
# Out:
# Continuous Columns:
# 	Store_Latitude
# 	Store_Longitude
# 	Order_Time
# 	Delivery_Time
# 	Drop_Distance
# 	Order_Date
#
# Discrete Columns Encoding:
# 	Agent_Age: {15: 0, 20: 1, 21: 2, 22: 3, 23: 4, 24: 5, 25: 6, 26: 7, 27: 8, 28: 9, 29: 10, 30: 11, 31: 12, 32: 13, 33: 14, 34: 15, 35: 16, 36: 17, 37: 18, 38: 19, 39: 20, 50: 21}
# 	Weather: {'Cloudy': 0, 'Fog': 1, 'Sandstorms': 2, 'Stormy': 3, 'Sunny': 4, 'Windy': 5, 'nan': 6}
# 	Traffic: {'High ': 0, 'Jam ': 1, 'Low ': 2, 'Medium ': 3, 'NaN ': 4}
# 	Vehicle: {'bicycle ': 0, 'motorcycle ': 1, 'scooter ': 2, 'van': 3}
# 	Area: {'Metropolitian ': 0, 'Other': 1, 'Semi-Urban ': 2, 'Urban ': 3}
# 	Category: {'Apparel': 0, 'Books': 1, 'Clothing': 2, 'Cosmetics': 3, 'Electronics': 4, 'Grocery': 5, 'Home': 6, 'Jewelry': 7, 'Kitchen': 8, 'Outdoors': 9, 'Pet Supplies': 10, 'Shoes': 11, 'Skincare': 12, 'Snacks': 13, 'Sports': 14, 'Toys': 15}
# 	Wait_Time: {5.0: 0, 10.0: 1, 15.0: 2, 'nan': 3}
# 	Dissatisfied: {0: 0, 1: 1}

# %%
dta.data_quality_check(miss_thres=0.);

# %%
dta.dist_plot();

# %%
dta.corr_heatmap(corr_method='dcorr', cluster=True);
dta.corr_heatmap(corr_method='dcorr', partial=True, cluster=True, linkage_method='single');
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/pandas/core/internals/blocks.py:395: RuntimeWarning: invalid value encountered in sqrt
#   result = func(self.values, **kwargs)

# %%
dta.pairplot(y_vars='Delivery_Time')

# %%
dta.dist_plot_by_categ('Traffic', kind='hist');

# %%
dta.df.to_csv('../Processed/Amazon.csv')
print(dta.cont_cols)
dta.df
# Out:
# ['Store_Latitude', 'Store_Longitude', 'Order_Time', 'Delivery_Time', 'Drop_Distance', 'Order_Date']
#                Agent_Age  Store_Latitude  Store_Longitude  Order_Date  \
# Order_ID
# ialx566343618         18       22.745049        75.892471     19070.0
# akqg208421122         15       12.913041        77.683237     19076.0
# njpu434582536          4       12.914264        77.678400     19070.0
# rjto796129700         19       11.003669        76.976494     19087.0
# zguw716275638         13       12.972793        80.249982     19077.0
# ...                  ...             ...              ...         ...
# jlxf819993117         11       26.902328        75.794257     19075.0
# aevx342135787          2             NaN              NaN     19039.0
# xnek760674819         11       13.022394        80.242439     19062.0
# cynl434665991          1       11.001753        76.986241     19058.0
# nsyz997960170          4       23.351058        85.325731     19053.0
#
#                Order_Time  Weather  Traffic  Vehicle  Area  Delivery_Time  \
# Order_ID
# ialx566343618       690.0        4        0        1     3          120.0
# akqg208421122      1185.0        3        1        2     0          165.0
# njpu434582536       510.0        2        2        1     3          130.0
# rjto796129700      1080.0        4        3        1     0          105.0
# zguw716275638       810.0        0        0        2     0          150.0
# ...                   ...      ...      ...      ...   ...            ...
# jlxf819993117       695.0        5        0        1     0          160.0
# aevx342135787      1195.0        5        1        1     0          180.0
# xnek760674819      1430.0        0        2        2     0           80.0
# cynl434665991       815.0        0        0        1     0          130.0
# nsyz997960170      1030.0        1        3        2     0          180.0
#
#                Category  Drop_Distance  Wait_Time  Dissatisfied
# Order_ID
# ialx566343618         2       3.020737          2             0
# akqg208421122         4      20.143737          0             0
# njpu434582536        14       1.549693          2             1
# rjto796129700         3       7.774497          1             0
# zguw716275638        15       6.197898          2             0
# ...                 ...            ...        ...           ...
# jlxf819993117         6       1.488112          1             0
# aevx342135787         7            NaN          2             0
# xnek760674819         6       4.648024          3             0
# cynl434665991         8       6.219668          0             0
# nsyz997960170         3      12.057294          0             0
#
# [43739 rows x 14 columns]

# %%
dta.df.dtypes
# Out:
# Agent_Age            int64
# Store_Latitude     float64
# Store_Longitude    float64
# Order_Date         float64
# Order_Time         float64
# Weather              int64
# Traffic              int64
# Vehicle              int64
# Area                 int64
# Delivery_Time      float64
# Category             int64
# Drop_Distance      float64
# Wait_Time            int64
# Dissatisfied         int64
# dtype: object
